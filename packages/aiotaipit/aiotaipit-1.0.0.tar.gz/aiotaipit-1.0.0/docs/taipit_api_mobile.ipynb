# %%
from pprint import pprint
import time
import requests
from datetime import datetime

# %%
client_id = '1_34mi8uiv22iowgsc0wggk0c8888cc80s8gk80gco00g0gko8ko'
client_secret = '15lkcj9ytmm8440ggsco8ogo4ockwgcg04okokcwokkk8cksk8'
# demo user
# some values are not available for a demo user,
# use login password of a real user
username = "guest@taipit.ru"
password = "guest"

# %%
BASE_URL = "https://cloud.meters.taipit.ru"
API_URL = f"{BASE_URL}/api"

# %%
s = requests.Session()

# %%
# Request access token
print("Request access token")
payload = {
    'grant_type': 'password',
    'username': username,
    'password': password,
    'client_id': client_id,
    'client_secret': client_secret
}
url = f"{BASE_URL}/oauth/v2/token"
r = s.post(url, data=payload)
print(f'URL: {r.url}')
print(f'Status: {r.status_code}')
token = r.json()
print('Response:')
pprint(token)
token["expires_in"] = int(token["expires_in"])
token["expires_at"] = time.time() + token["expires_in"]
dt = datetime.fromtimestamp(token["expires_at"])
pprint(dt)
# Out:
# Request access token
# URL: https://cloud.meters.taipit.ru/oauth/v2/token
# Status: 200
# Response:
# {'access_token': 'NjFhY2RmNmRkNjdjNzMwNTFkMjU2Y2ZhNGY2YTA5NjU4Y2MzM2RjODRlYzQ4ODJkYzEwOTNhN2EyZDA3NzM5YQ',
#  'expires_in': 3600,
#  'refresh_token': 'OWYzOTI4NzI1NmFkOGJmOTJiZGM0ZmQ5MTdmODdkZjM5OTM0ODU1ODVkNjRhZjUyZmY1ZGQ5NGM0YzNiYzk4NQ',
#  'scope': None,
#  'token_type': 'bearer'}
# datetime.datetime(2023, 1, 12, 14, 4, 21, 220974)

# %%
# Request refresh access token

print("Request refresh access token")
payload = {
    'grant_type': 'refresh_token',
    'refresh_token': token['refresh_token'],
    'client_id': client_id,
    'client_secret': client_secret
}
url = f"{BASE_URL}/oauth/v2/token"
r = s.post(url, data=payload)
print(f'URL: {r.url}')
print(f'Status: {r.status_code}')
new_token = r.json()
print('Response:')
pprint(new_token)
new_token["expires_in"] = int(new_token["expires_in"])
new_token["expires_at"] = time.time() + new_token["expires_in"]
dt = datetime.fromtimestamp(new_token["expires_at"])
pprint(dt)
# Out:
# Request refresh access token
# URL: https://cloud.meters.taipit.ru/oauth/v2/token
# Status: 200
# Response:
# {'access_token': 'OWY3NWRhZmNkZDI0YmI0OWM0MTlhMDUwMTMxNGNlZTYxYWJhMDAyMjk0NGRhMzZjYzZmOTk5YzgwM2U5MzE1NA',
#  'expires_in': 3600,
#  'refresh_token': 'OWYzOTI4NzI1NmFkOGJmOTJiZGM0ZmQ5MTdmODdkZjM5OTM0ODU1ODVkNjRhZjUyZmY1ZGQ5NGM0YzNiYzk4NQ',
#  'scope': None,
#  'token_type': 'bearer'}
# datetime.datetime(2023, 1, 12, 14, 4, 21, 354425)

# %%
auth = {"Authorization": f"Bearer {token['access_token']}"}

# %%
# Settings
print('Settings')
sections = ['regions', 'meterTypes', 'controllers']
params = {'sections': ','.join(sections)}
url = f"{API_URL}/config/settings"
r = s.get(url, params=params, headers=auth)
print(f'URL: {r.url}')
print(f'Status: {r.status_code}')
settings = r.json()
print('Response:')
pprint(settings)
# Out:
# Settings
# URL: https://cloud.meters.taipit.ru/api/config/settings?sections=regions%2CmeterTypes%2Ccontrollers
# Status: 200
# Response:
# {'controllers': [],
#  'meterTypes': [{'category': 0,
#                  'helperHtml': '',
#                  'id': 16,
#                  'manufacturer': 'НЕВА',
#                  'model': 'МТ 114 (Wi-Fi)',
#                  'netAddressAlgorithm': 0,
#                  'pulse': False,
#                  'serialLength': 8,
#                  'taipit': True,
#                  'userPassword': '000000',
#                  'wifi': True,
#                  'withController': True},
#                 {'category': 0,
#                  'helperHtml': '',
#                  'id': 22,
#                  'manufacturer': 'НЕВА',
#                  'model': 'МТ 115 (GSM)',
#                  'netAddressAlgorithm': 0,
#                  'pulse': False,
#                  'serialLength': 8,
#                  'taipit': True,
#                  'transformer': True,
#                  'userPassword': None,
#                  'withController': True},
#                 {'category': 0,
#                  'helperHtml': '',
#                  'id': 21,
#                  'manufacturer': 'НЕВА',
#                  'model': 'МТ 124 (Wi-Fi)',
#                  'netAddressAlgorithm': 0,
#                  'pulse': False,
#                  'serialLength': 8,
#                  'taipit': True,
#                  'userPassword': '000000',
#                  'wifi': True,
#                  'withController': True},
#                 {'category': 0,
#                  'helperHtml': '',
#                  'id': 15,
#                  'manufacturer': 'НЕВА',
#                  'model': 'МТ 315 (GSM)',
#                  'netAddressAlgorithm': 0,
#                  'pulse': False,
#                  'serialLength': 8,
#                  'taipit': True,
#                  'threePhase': True,
#                  'transformer': True,
#                  'userPassword': None,
#                  'withController': True}],
#  'meterTypesFull': [{'category': 0,
#                      'helperHtml': '',
#                      'id': 19,
#                      'manufacturer': 'Schneider',
#                      'maxAddressValue': 247,
#                      'model': 'iEM3155',
#                      'netAddressAlgorithm': 9,
#                      'pulse': False,
#                      'serialLength': 10,
#                      'threePhase': True,
#                      'transformer': True,
#                      'userPassword': None},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 14,
#                      'manufacturer': 'Берегун',
#                      'model': '1-2 (белый)',
#                      'netAddressAlgorithm': 7,
#                      'netAddressLength': 12,
#                      'pulse': False,
#                      'serialLength': 6,
#                      'userPassword': None},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'hexInSerial': True,
#                      'id': 13,
#                      'manufacturer': 'Берегун',
#                      'model': '3-1 (красный)',
#                      'netAddressAlgorithm': 7,
#                      'netAddressLength': 12,
#                      'pulse': False,
#                      'serialLength': 7,
#                      'userPassword': None},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 8,
#                      'manufacturer': 'БЕТАР',
#                      'model': 'ЭСО-211',
#                      'netAddressAlgorithm': 4,
#                      'pulse': False,
#                      'serialLength': 8,
#                      'userPassword': '000000'},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 18,
#                      'manufacturer': 'Гермес',
#                      'model': 'Импульсный',
#                      'netAddressAlgorithm': 8,
#                      'noNeedTask': True,
#                      'pulse': False,
#                      'serialLength': 0,
#                      'transformer': True,
#                      'userPassword': None},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 2,
#                      'manufacturer': 'Меркурий',
#                      'maxAddressValueIfNotCustom': 999999,
#                      'model': '200',
#                      'netAddressAlgorithm': 2,
#                      'pulse': False,
#                      'serialLength': 8,
#                      'userPassword': None},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 12,
#                      'manufacturer': 'Меркурий',
#                      'model': '206, 203.2Т',
#                      'netAddressAlgorithm': 0,
#                      'pulse': False,
#                      'serialLength': 8,
#                      'userPassword': None},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 1,
#                      'manufacturer': 'Меркурий',
#                      'maxAddressValue': 239,
#                      'model': '230',
#                      'netAddressAlgorithm': 1,
#                      'pulse': False,
#                      'serialLength': 8,
#                      'threePhase': True,
#                      'transformer': True,
#                      'userPassword': '111111'},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 5,
#                      'manufacturer': 'Меркурий',
#                      'maxAddressValue': 253,
#                      'model': '233, 234, 236',
#                      'netAddressAlgorithm': 1,
#                      'pulse': False,
#                      'serialLength': 8,
#                      'threePhase': True,
#                      'transformer': True,
#                      'userPassword': '111111'},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 24,
#                      'manufacturer': 'Милур',
#                      'model': '0300-0399',
#                      'netAddressAlgorithm': 11,
#                      'pulse': False,
#                      'serialLength': 0,
#                      'transformer': True,
#                      'userPassword': None},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 16,
#                      'manufacturer': 'НЕВА',
#                      'model': 'МТ 114 (Wi-Fi)',
#                      'netAddressAlgorithm': 0,
#                      'pulse': False,
#                      'serialLength': 8,
#                      'taipit': True,
#                      'userPassword': '000000',
#                      'wifi': True,
#                      'withController': True},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 10,
#                      'manufacturer': 'НЕВА',
#                      'model': 'МТ 114, МТ 124',
#                      'netAddressAlgorithm': 0,
#                      'pulse': False,
#                      'serialLength': 0,
#                      'userPassword': '000000'},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 22,
#                      'manufacturer': 'НЕВА',
#                      'model': 'МТ 115 (GSM)',
#                      'netAddressAlgorithm': 0,
#                      'pulse': False,
#                      'serialLength': 8,
#                      'taipit': True,
#                      'transformer': True,
#                      'userPassword': None,
#                      'withController': True},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 9,
#                      'manufacturer': 'НЕВА',
#                      'model': 'МТ 123',
#                      'netAddressAlgorithm': 0,
#                      'pulse': False,
#                      'serialLength': 0,
#                      'userPassword': '000000'},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 21,
#                      'manufacturer': 'НЕВА',
#                      'model': 'МТ 124 (Wi-Fi)',
#                      'netAddressAlgorithm': 0,
#                      'pulse': False,
#                      'serialLength': 8,
#                      'taipit': True,
#                      'userPassword': '000000',
#                      'wifi': True,
#                      'withController': True},
#                     {'category': 0,
#                      'helperHtml': '<div '
#                                    'class="meter-add_type-neva324">Некоторые '
#                                    'экземпляры данного типа счетчиков имеют '
#                                    'серийный номер, состоящий из 6&nbsp;цифр, '
#                                    'например, 123456. В этом случае, при '
#                                    'заполнении поля "Серийный номер" '
#                                    'необходимо добавить в начале 00, например, '
#                                    '<strong>00</strong>123456.</div>',
#                      'id': 11,
#                      'manufacturer': 'НЕВА',
#                      'model': 'МТ 313, МТ 323, МТ 324',
#                      'netAddressAlgorithm': 0,
#                      'pulse': False,
#                      'serialLength': 0,
#                      'threePhase': True,
#                      'transformer': True,
#                      'userPassword': '000000'},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 15,
#                      'manufacturer': 'НЕВА',
#                      'model': 'МТ 315 (GSM)',
#                      'netAddressAlgorithm': 0,
#                      'pulse': False,
#                      'serialLength': 8,
#                      'taipit': True,
#                      'threePhase': True,
#                      'transformer': True,
#                      'userPassword': None,
#                      'withController': True},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 6,
#                      'kInMeter': True,
#                      'manufacturer': 'НЗиФ',
#                      'model': 'ПСЧ-4TM',
#                      'netAddressAlgorithm': 0,
#                      'no3Tariffs': True,
#                      'pulse': False,
#                      'serialLength': 10,
#                      'threePhase': True,
#                      'transformer': True,
#                      'userPassword': '000000'},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 7,
#                      'kInMeter': True,
#                      'manufacturer': 'НЗиФ',
#                      'model': 'СЭТ-4TM',
#                      'netAddressAlgorithm': 0,
#                      'no3Tariffs': True,
#                      'pulse': False,
#                      'serialLength': 10,
#                      'threePhase': True,
#                      'transformer': True,
#                      'userPassword': '000000'},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 20,
#                      'kInMeter': True,
#                      'manufacturer': 'НЗиФ',
#                      'maxAddressValue': 239,
#                      'model': 'СЭТ/ПСЧ старый',
#                      'netAddressAlgorithm': 1,
#                      'no3Tariffs': True,
#                      'pulse': False,
#                      'serialLength': 8,
#                      'threePhase': True,
#                      'transformer': True,
#                      'userPassword': '000000'},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 17,
#                      'manufacturer': 'Универсальный',
#                      'model': 'Импульсный',
#                      'netAddressAlgorithm': None,
#                      'pulse': True,
#                      'serialLength': 0,
#                      'transformer': True,
#                      'userPassword': None},
#                     {'category': 0,
#                      'helperHtml': '<div '
#                                    'class="meter-add_type-energomera"><img '
#                                    'src="/assets/images/energomera-help.png">Серийный '
#                                    'номер расположен на лицевой стороне '
#                                    'счётчика и состоит из 15 цифр. Например, '
#                                    '012345678901234.</div>',
#                      'id': 3,
#                      'manufacturer': 'Энергомера',
#                      'model': 'CE301, CE303, CE102М (протокол ГОСТ 61107)',
#                      'netAddressAlgorithm': 3,
#                      'pulse': False,
#                      'serialLength': 15,
#                      'threePhase': True,
#                      'transformer': True,
#                      'userPassword': None},
#                     {'category': 0,
#                      'helperHtml': '',
#                      'id': 23,
#                      'manufacturer': 'Энергомера',
#                      'model': 'СЕ102 R5.1 (протокол СЕ)',
#                      'netAddressAlgorithm': 10,
#                      'pulse': False,
#                      'serialLength': 15,
#                      'userPassword': '777777'}],
#  'regions': [{'id': 1, 'name': 'Республика Адыгея'},
#              {'id': 2, 'name': 'Республика Башкортостан'},
#              {'id': 3, 'name': 'Республика Бурятия'},
#              {'id': 4, 'name': 'Республика Алтай'},
#              {'id': 5, 'name': 'Республика Дагестан'},
#              {'id': 6, 'name': 'Республика Ингушетия'},
#              {'id': 7, 'name': 'Кабардино-Балкарская республика'},
#              {'id': 8, 'name': 'Республика Калмыкия'},
#              {'id': 9, 'name': 'Карачаево-Черкесская республика'},
#              {'id': 10, 'name': 'Республика Карелия'},
#              {'id': 11, 'name': 'Республика Коми'},
#              {'id': 12, 'name': 'Республика Марий Эл'},
#              {'id': 13, 'name': 'Республика Мордовия'},
#              {'id': 14, 'name': 'Республика Саха (Якутия)'},
#              {'id': 15, 'name': 'Республика Северная Осетия — Алания'},
#              {'id': 16, 'name': 'Республика Татарстан'},
#              {'id': 17, 'name': 'Республика Тыва'},
#              {'id': 18, 'name': 'Удмуртская республика'},
#              {'id': 19, 'name': 'Республика Хакасия'},
#              {'id': 20, 'name': 'Чеченская республика'},
#              {'id': 21, 'name': 'Чувашская республика'},
#              {'id': 22, 'name': 'Алтайский край'},
#              {'id': 23, 'name': 'Краснодарский край'},
#              {'id': 24, 'name': 'Красноярский край'},
#              {'id': 25, 'name': 'Приморский край'},
#              {'id': 26, 'name': 'Ставропольский край'},
#              {'id': 27, 'name': 'Хабаровский край'},
#              {'id': 28, 'name': 'Амурская область'},
#              {'id': 29, 'name': 'Архангельская область'},
#              {'id': 30, 'name': 'Астраханская область'},
#              {'id': 31, 'name': 'Белгородская область'},
#              {'id': 32, 'name': 'Брянская область'},
#              {'id': 33, 'name': 'Владимирская область'},
#              {'id': 34, 'name': 'Волгоградская область'},
#              {'id': 35, 'name': 'Вологодская область'},
#              {'id': 36, 'name': 'Воронежская область'},
#              {'id': 37, 'name': 'Ивановская область'},
#              {'id': 38, 'name': 'Иркутская область'},
#              {'id': 39, 'name': 'Калининградская область'},
#              {'id': 40, 'name': 'Калужская область'},
#              {'id': 41, 'name': 'Камчатский край'},
#              {'id': 42, 'name': 'Кемеровская область'},
#              {'id': 43, 'name': 'Кировская область'},
#              {'id': 44, 'name': 'Костромская область'},
#              {'id': 45, 'name': 'Курганская область'},
#              {'id': 46, 'name': 'Курская область'},
#              {'id': 47, 'name': 'Ленинградская область'},
#              {'id': 48, 'name': 'Липецкая область'},
#              {'id': 49, 'name': 'Магаданская область'},
#              {'id': 50, 'name': 'Московская область'},
#              {'id': 51, 'name': 'Мурманская область'},
#              {'id': 52, 'name': 'Нижегородская область'},
#              {'id': 53, 'name': 'Новгородская область'},
#              {'id': 54, 'name': 'Новосибирская область'},
#              {'id': 55, 'name': 'Омская область'},
#              {'id': 56, 'name': 'Оренбургская область'},
#              {'id': 57, 'name': 'Орловская область'},
#              {'id': 58, 'name': 'Пензенская область'},
#              {'id': 59, 'name': 'Пермский край'},
#              {'id': 60, 'name': 'Псковская область'},
#              {'id': 61, 'name': 'Ростовская область'},
#              {'id': 62, 'name': 'Рязанская область'},
#              {'id': 63, 'name': 'Самарская область'},
#              {'id': 64, 'name': 'Саратовская область'},
#              {'id': 65, 'name': 'Сахалинская область'},
#              {'id': 66, 'name': 'Свердловская область'},
#              {'id': 67, 'name': 'Смоленская область'},
#              {'id': 68, 'name': 'Тамбовская область'},
#              {'id': 69, 'name': 'Тверская область'},
#              {'id': 70, 'name': 'Томская область'},
#              {'id': 71, 'name': 'Тульская область'},
#              {'id': 72, 'name': 'Тюменская область'},
#              {'id': 73, 'name': 'Ульяновская область'},
#              {'id': 74, 'name': 'Челябинская область'},
#              {'id': 75, 'name': 'Забайкальский край'},
#              {'id': 76, 'name': 'Ярославская область'},
#              {'id': 77, 'name': 'Москва'},
#              {'id': 78, 'name': 'Санкт-Петербург'},
#              {'id': 79, 'name': 'Еврейская автономная область'},
#              {'id': 83, 'name': 'Ненецкий автономный округ'},
#              {'id': 86, 'name': 'Ханты-Мансийский автономный округ - Югра'},
#              {'id': 87, 'name': 'Чукотский автономный округ'},
#              {'id': 89, 'name': 'Ямало-Ненецкий автономный округ'},
#              {'id': 91, 'name': 'Республика Крым'},
#              {'id': 92, 'name': 'Севастополь'}]}

# %%
# Warnings
print('Warnings')
params = {'action': 'getEntries'}
url = f"{API_URL}/warnings/list"
r = s.get(url, params=params, headers=auth)
print(f'URL: {r.url}')
print(f'Status: {r.status_code}')
warnings = r.json()
print('Response:')
pprint(warnings)
# Out:
# Warnings
# URL: https://cloud.meters.taipit.ru/api/warnings/list?action=getEntries
# Status: 200
# Response:
# {'data': [], 'success': True}

# %%
# Current user
print('Current user')
url = f"{API_URL}/user/getuser"
r = s.get(url, headers=auth)
print(f'URL: {r.url}')
print(f'Status: {r.status_code}')
user = r.json()
print('Response:')
pprint(user)
# Out:
# Current user
# URL: https://cloud.meters.taipit.ru/api/user/getuser
# Status: 200
# Response:
# {'aboutMe': None,
#  'id': 'c29bab91-6898-11e8-bbef-fa163e7bc62b',
#  'isAdmin': False,
#  'isGuest': True,
#  'isMobileAdmin': False,
#  'newWarningsCount': 0,
#  'photo': '/uploads/user/photo/profile_default.jpg',
#  'username': 'Guest'}

# %%
# Advanced User Info
print('Advanced User info')
url = f"{API_URL}/user/getuserinfo/{user['id']}"
r = s.get(url, headers=auth)
print(f'URL: {r.url}')
print(f'Status: {r.status_code}')
user_info = r.json()
print('Response:')
pprint(user_info)
# Out:
# Advanced User info
# URL: https://cloud.meters.taipit.ru/api/user/getuserinfo/c29bab91-6898-11e8-bbef-fa163e7bc62b
# Status: 200
# Response:
# {'aboutMe': None,
#  'birthDate': None,
#  'city': None,
#  'email': 'guest@taipit.ru',
#  'firstName': None,
#  'id': 'c29bab91-6898-11e8-bbef-fa163e7bc62b',
#  'isAdmin': False,
#  'isMobileAdmin': False,
#  'lastName': None,
#  'middleName': None,
#  'organization': None,
#  'phone': None,
#  'photo': '/uploads/user/photo/profile_default.jpg',
#  'region': None,
#  'username': 'Guest'}

# %%
# All meters and readings
print("All meters and values")
url = f"{API_URL}/meter/list-all"
r = s.get(url, headers=auth)
print(f'URL: {r.url}')
print(f'Status: {r.status_code}')
all_meters_values = r.json()
print('Response:')
pprint(all_meters_values)
# Out:
# All meters and values
# URL: https://cloud.meters.taipit.ru/api/meter/list-all
# Status: 200
# Response:
# [{'address': 'Санкт-Петербург, Ворошилова, 2',
#   'category': 0,
#   'ecometerdata': {'P_aver': 0.12983303279391,
#                    'P_averSmall': 0.085475130516735,
#                    'P_averSmall_': 61.542093972049,
#                    'P_aver_': 93.479783611612,
#                    'P_aver_TF1': False,
#                    'P_aver_TF2': False,
#                    'P_aver_TF31': False,
#                    'P_aver_TF32': False,
#                    'P_aver_TF33': False,
#                    'P_norm': 0.59533333333333,
#                    'currentTS': 1673528662,
#                    'ecoStatus': None,
#                    'lastReading': {'energy_a': 1069.97,
#                                    'energy_t1_a': 854.6,
#                                    'energy_t2_a': 215.37,
#                                    'energy_t3_a': 0,
#                                    'ts_tz': 1673528423,
#                                    'value': 0.838},
#                    'meterCategory': 0,
#                    'time': 1673528662,
#                    'timezone': 3,
#                    'trend': -31.937689639563,
#                    'trendTF1': False,
#                    'trendTF2': False},
#   'id': 2147485997,
#   'isLowDataFreq': False,
#   'isOwner': False,
#   'isVirtual': 0,
#   'metername': 'НЕВА МТ 114 (Wi-Fi) (22001110)',
#   'owner': {'peopleNumber': None, 'type': 0, 'typeCode': 'person'},
#   'serialNumber': '22001110',
#   'usericopath': '/uploads/user/photo/3edba895933a54540fbdb88614f24f480a9eeb68.png',
#   'username': 'Компания Тайпит',
#   'waterHot': False},
#  {'address': 'Санкт-Петербург, Ворошилова, 2',
#   'category': 0,
#   'ecometerdata': {'P_aver': 0.18627698725044,
#                    'P_averSmall': 0.12128327125868,
#                    'P_averSmall_': 87.323955306246,
#                    'P_aver_': 134.11943082032,
#                    'P_aver_TF1': False,
#                    'P_aver_TF2': False,
#                    'P_aver_TF31': False,
#                    'P_aver_TF32': False,
#                    'P_aver_TF33': False,
#                    'P_norm': 0.87733333333333,
#                    'currentTS': 1673528662,
#                    'ecoStatus': None,
#                    'lastReading': {'energy_a': 11693.47,
#                                    'energy_t1_a': 10517.85,
#                                    'energy_t2_a': 1175.62,
#                                    'energy_t3_a': 0,
#                                    'ts_tz': 1673528427,
#                                    'value': 1.296},
#                    'meterCategory': 0,
#                    'time': 1673528662,
#                    'timezone': 3,
#                    'trend': -46.795475514069,
#                    'trendTF1': False,
#                    'trendTF2': False},
#   'id': 2147485996,
#   'isLowDataFreq': False,
#   'isOwner': False,
#   'isVirtual': 0,
#   'metername': 'НЕВА МТ 114 (Wi-Fi) (22001114)',
#   'owner': {'peopleNumber': None, 'type': 0, 'typeCode': 'person'},
#   'serialNumber': '22001114',
#   'usericopath': '/uploads/user/photo/3edba895933a54540fbdb88614f24f480a9eeb68.png',
#   'username': 'Компания Тайпит',
#   'waterHot': False}]

# %%
# All meters of current user
print("All meters of current user")
url = f"{API_URL}/meter/list-owner"
r = s.get(url, headers=auth)
print(f'URL: {r.url}')
print(f'Status: {r.status_code}')
meters = r.json()
print('Response:')
pprint(meters)
# Out:
# All meters of current user
# URL: https://cloud.meters.taipit.ru/api/meter/list-owner
# Status: 200
# Response:
# []

# %%
# Meter readings
url = f"{API_URL}/bmd/all"
for meter in all_meters_values:
#for meter in meters:
    print(f"Meter ID: {meter['id']}")
    params = {'id': meter['id']}
    r = s.get(url, params=params, headers=auth)
    print(f'URL: {r.url}')
    print(f'Status: {r.status_code}')
    values = r.json()
    print('Response:')
    pprint(values)
    print("\n")
# Out:
# Meter ID: 2147485997
# URL: https://cloud.meters.taipit.ru/api/bmd/all?id=2147485997
# Status: 200
# Response:
# {'controller': {'balance': [],
#                 'expired': False,
#                 'id': '11194495496',
#                 'isVirtual': False,
#                 'owner': False,
#                 'signal': 28},
#  'economizer': {'P_aver': 0.12983303279391,
#                 'P_averSmall': 0.085475130516735,
#                 'P_averSmall_': 61.542093972049,
#                 'P_aver_': 93.479783611612,
#                 'P_aver_TF1': 91.369427288102,
#                 'P_aver_TF2': 2.1103563235096,
#                 'P_aver_TF31': 15.517620075475,
#                 'P_aver_TF32': 2.1103563235096,
#                 'P_aver_TF33': 75.851807212628,
#                 'P_norm': 0.59533333333333,
#                 'addParams': {'dates': {'i': '12.01.2023 13:00',
#                                         'u': '12.01.2023 13:00'},
#                               'otherStatus': 1,
#                               'transStatus': 0,
#                               'values': {'cos': ['-'],
#                                          'i': ['3.53'],
#                                          'u': ['237.3']}},
#                 'currentTS': 1673528662,
#                 'ecoStatus': None,
#                 'lastReading': {'energy_a': 1069.97,
#                                 'energy_t1_a': 854.6,
#                                 'energy_t2_a': 215.37,
#                                 'energy_t3_a': 0,
#                                 'ts_tz': 1673528423,
#                                 'value': 0.838},
#                 'meterCategory': 0,
#                 'time': 1673528662,
#                 'timezone': 3,
#                 'trend': -31.937689639563,
#                 'trendTF1': False,
#                 'trendTF2': False},
#  'hour': [{'k_iu': 1,
#            'ts_tz': 1673395200,
#            'value': '{"1673395200":{"t1":{"energy_a":1062.31,"ts_tz":1673395243,"energy_t1_a":847.31,"energy_t2_a":215,"energy_t3_a":0},"t2":{"energy_a":1062.32,"ts_tz":1673398851,"energy_t1_a":847.31,"energy_t2_a":215.01,"energy_t3_a":0},"value":0.01,"valueT1":0,"valueT2":0.01,"valueT3":0},"1673398800":{"t1":{"energy_a":1062.32,"ts_tz":1673398851,"energy_t1_a":847.31,"energy_t2_a":215.01,"energy_t3_a":0},"t2":{"energy_a":1062.33,"ts_tz":1673402459,"energy_t1_a":847.31,"energy_t2_a":215.02,"energy_t3_a":0},"value":0.01,"valueT1":0,"valueT2":0.01,"valueT3":0},"1673402400":{"t1":{"energy_a":1062.33,"ts_tz":1673402459,"energy_t1_a":847.31,"energy_t2_a":215.02,"energy_t3_a":0},"t2":{"energy_a":1062.34,"ts_tz":1673406007,"energy_t1_a":847.32,"energy_t2_a":215.02,"energy_t3_a":0},"value":0.01,"valueT1":0.01,"valueT2":0,"valueT3":0},"1673406000":{"t1":{"energy_a":1062.34,"ts_tz":1673406007,"energy_t1_a":847.32,"energy_t2_a":215.02,"energy_t3_a":0},"t2":{"energy_a":1062
"energy_t2_a":215.37,"energy_t3_a":0},"t2":{"energy_a":1068.54,"ts_tz":1673499614,"energy_t1_a":853.17,"energy_t2_a":215.37,"energy_t3_a":0},"value":0.01,"valueT1":0.01,"valueT2":0,"valueT3":0},"1673499600":{"t1":{"energy_a":1068.54,"ts_tz":1673499614,"energy_t1_a":853.17,"energy_t2_a":215.37,"energy_t3_a":0},"t2":{"energy_a":1068.55,"ts_tz":1673503222,"energy_t1_a":853.18,"energy_t2_a":215.37,"energy_t3_a":0},"value":0.01,"valueT1":0.01,"valueT2":0,"valueT3":0},"1673503200":{"t1":{"energy_a":1068.55,"ts_tz":1673503222,"energy_t1_a":853.18,"energy_t2_a":215.37,"energy_t3_a":0},"t2":{"energy_a":1068.56,"ts_tz":1673506830,"energy_t1_a":853.19,"energy_t2_a":215.37,"energy_t3_a":0},"value":0.01,"valueT1":0.01,"valueT2":0,"valueT3":0},"1673506800":{"t1":{"energy_a":1068.56,"ts_tz":1673506830,"energy_t1_a":853.19,"energy_t2_a":215.37,"energy_t3_a":0},"t2":{"energy_a":1068.57,"ts_tz":1673510438,"energy_t1_a":853.2,"energy_t2_a":215.37,"energy_t3_a":0},"value":0.01,"valueT1":0.01,"valueT2":0,"valueT3":0},"1673510400":{"t1":{"energy_a":1068.57,"ts_tz":1673510438,"energy_t1_a":853.2,"energy_t2_a":215.37,"energy_t3_a":0},"t2":{"energy_a":1068.58,"ts_tz":1673514046,"energy_t1_a":853.21,"energy_t2_a":215.37,"energy_t3_a":0},"value":0.01,"valueT1":0.01,"valueT2":0,"valueT3":0},"1673514000":{"t1":{"energy_a":1068.58,"ts_tz":1673514046,"energy_t1_a":853.21,"energy_t2_a":215.37,"energy_t3_a":0},"t2":{"energy_a":1068.58,"ts_tz":1673517657,"energy_t1_a":853.21,"energy_t2_a":215.37,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1673517600":{"t1":{"energy_a":1068.58,"ts_tz":1673517657,"energy_t1_a":853.21,"energy_t2_a":215.37,"energy_t3_a":0},"t2":{"energy_a":1068.59,"ts_tz":1673521206,"energy_t1_a":853.22,"energy_t2_a":215.37,"energy_t3_a":0},"value":0.01,"valueT1":0.01,"valueT2":0,"valueT3":0},"1673521200":{"t1":{"energy_a":1068.59,"ts_tz":1673521206,"energy_t1_a":853.22,"energy_t2_a":215.37,"energy_t3_a":0},"t2":{"energy_a":1069.12,"ts_tz":1673524814,"energy_t1_a":853.75,"energy_t2_a":215.37,"energy_t3_a":0},"value":0.529,"valueT1":0.529,"valueT2":0,"valueT3":0},"1673524800":{"t1":{"energy_a":1069.12,"ts_tz":1673524814,"energy_t1_a":853.75,"energy_t2_a":215.37,"energy_t3_a":0},"t2":{"energy_a":1069.97,"ts_tz":1673528423,"energy_t1_a":854.6,"energy_t2_a":215.37,"energy_t3_a":0},"value":0.848,"valueT1":0.848,"valueT2":0,"valueT3":0},"1673528400":{"t1":{"energy_a":1069.97,"ts_tz":1673528423,"energy_t1_a":854.6,"energy_t2_a":215.37,"energy_t3_a":0},"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673532000":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673535600":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673539200":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":fal ...
#  'meter': {'address': 'Санкт-Петербург, Ворошилова, 2',
#            'category': 0,
#            'editAccessTypePermit': False,
#            'editPermit': False,
#            'freqReqStatus': -1,
#            'id': 2147485997,
#            'isConsumer': False,
#            'isExternal': False,
#            'isLowDataFreq': False,
#            'isOpen': True,
#            'isPulse': False,
#            'isSharedByLink': False,
#            'isViewer': True,
#            'isVirtual': False,
#            'liveMode': False,
#            'name': 'НЕВА МТ 114 (Wi-Fi) (22001110)',
#            'offerPermit': False,
#            'partner': True,
#            'prices': {'price': '3.92',
#                       'priceTF1': '4.51',
#                       'priceTF2': '2.44',
#                       'priceTF31': '4.61',
#                       'priceTF32': '2.44',
#                       'priceTF33': '3.92'},
#            'readingsPermit': False,
#            'requestSent': False,
#            'requestType': 2,
#            'serialNumber': '22001110',
#            'showCorpTariffsLink': False,
#            'showHourlyReportLink': False,
#            'subType': 0,
#            'subject': {'email': 'cloud@taipit.ru',
#                        'name': 'Компания Тайпит',
#                        'picture': '/uploads/user/photo/3edba895933a54540fbdb88614f24f480a9eeb68.png',
#                        'userId': 'a128bf64-01c0-11e8-bbef-fa163e7bc62b'},
#            'supplierPermit': False,
#            'switch': False,
#            'tariffsNum': None,
#            'viewSettingsPermit': False,
#            'warningsPermit': True,
#            'waterHot': False,
#            'withPermit': True},
#  'period': {'time': 1673528662,
#             'values': [{'energy_type': 'day',
#                         'k_iu': 1,
#                         'ts_tz': 1672531200,
#                         'value': '{"1672531200":{"t1":{"energy_a":1048.43,"ts_tz":1672531232,"energy_t1_a":834.69,"energy_t2_a":213.74,"energy_t3_a":0},"t2":{"energy_a":1048.64,"ts_tz":1672617654,"energy_t1_a":834.83,"energy_t2_a":213.81,"energy_t3_a":0},"value":0.21,"valueT1":0.14,"valueT2":0.07,"valueT3":0},"
"energy_a":1068.5,"ts_tz":1673481611,"energy_t1_a":853.14,"energy_t2_a":215.36,"energy_t3_a":0},"value":6.19,"valueT1":5.83,"valueT2":0.36,"valueT3":0},"1673481600":{"t1":{"energy_a":1068.5,"ts_tz":1673481611,"energy_t1_a":853.14,"energy_t2_a":215.36,"energy_t3_a":0},"t2":{"energy_a":1069.97,"ts_tz":1673528423,"energy_t1_a":854.6,"energy_t2_a":215.37,"energy_t3_a":0},"value":1.47,"valueT1":1.46,"valueT2":0.01,"valueT3":0},"1673568000":{"t1":{"energy_a":1069.97,"ts_tz":1673528423,"energy_t1_a":854.6,"energy_t2_a":215.37,"energy_t3_a":0},"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673654400":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673740800":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673827200":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673913600":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1674000000":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1674086400":{"t1": ...
#  'subTypesSettings': {'12': {'red_bg_warning_period': 86400},
#                       'live_refresh_period': 60},
#  'viewers': 'public'}
#
#
# Meter ID: 2147485996
# URL: https://cloud.meters.taipit.ru/api/bmd/all?id=2147485996
# Status: 200
# Response:
# {'controller': {'balance': [],
#                 'expired': False,
#                 'id': '111944954e9',
#                 'isVirtual': False,
#                 'owner': False,
#                 'signal': 16},
#  'economizer': {'P_aver': 0.18627698725044,
#                 'P_averSmall': 0.12128327125868,
#                 'P_averSmall_': 87.323955306246,
#                 'P_aver_': 134.11943082032,
#                 'P_aver_TF1': 134.09942866815,
#                 'P_aver_TF2': 0.020002152167379,
#                 'P_aver_TF31': 16.86781492275,
#                 'P_aver_TF32': 0.020002152167379,
#                 'P_aver_TF33': 117.2316137454,
#                 'P_norm': 0.87733333333333,
#                 'addParams': {'dates': {'i': '12.01.2023 13:00',
#                                         'u': '12.01.2023 13:00'},
#                               'otherStatus': 1,
#                               'transStatus': 0,
#                               'values': {'cos': ['-'],
#                                          'i': ['5.66'],
#                                          'u': ['239.4']}},
#                 'currentTS': 1673528662,
#                 'ecoStatus': None,
#                 'lastReading': {'energy_a': 11693.47,
#                                 'energy_t1_a': 10517.85,
#                                 'energy_t2_a': 1175.62,
#                                 'energy_t3_a': 0,
#                                 'ts_tz': 1673528427,
#                                 'value': 1.296},
#                 'meterCategory': 0,
#                 'time': 1673528662,
#                 'timezone': 3,
#                 'trend': -46.795475514069,
#                 'trendTF1': False,
#                 'trendTF2': False},
#  'hour': [{'k_iu': 1,
#            'ts_tz': 1673395200,
#            'value': '{"1673395200":{"t1":{"energy_a":11680.06,"ts_tz":1673395263,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"t2":{"energy_a":11680.06,"ts_tz":1673398811,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1673398800":{"t1":{"energy_a":11680.06,"ts_tz":1673398811,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"t2":{"energy_a":11680.06,"ts_tz":1673402419,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1673402400":{"t1":{"energy_a":11680.06,"ts_tz":1673402419,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"t2":{"energy_a":11680.06,"ts_tz":1673406027,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1673406000":{"t1":{"energy_a":11680.06,"ts_tz":1673406027,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"t2":{"energy_a":11680.06,"ts_tz":1673409635,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1673409600":{"t1":{"energy_a":11680.06,"ts_tz":1673409635,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"t2":{"energy_a":11680.06,"ts_tz":1673413243,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1673413200":{"t1":{"energy_a":11680.06,"ts_tz":1673413243,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"t2":{"energy_a":11680.06,"ts_tz":1673416851,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1673416800":{"t1":{"energy_a":11680.06,"ts_tz":1673416851,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"t2":{"energy_a":11680.06,"ts_tz":1673420459,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1673420400":{"t1":{"energy_a":11680.06,"ts_tz":1673420459,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"t2":{"energy_a":11680.06,"ts_tz":1673424007,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1673424000":{"t1":{"energy_a":11680.06,"ts_tz":1673424007,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"t2":{"energy_a":11680.07,"ts_tz":1673427615,"energy_t1_a":10504.77,"energy_t2_a":1175.3,"energy_t3_a":0},"value":
"energy_t2_a":1175.62,"energy_t3_a":0},"t2":{"energy_a":11693.47,"ts_tz":1673528427,"energy_t1_a":10517.85,"energy_t2_a":1175.62,"energy_t3_a":0},"value":1.426,"valueT1":1.426,"valueT2":0,"valueT3":0},"1673528400":{"t1":{"energy_a":11693.47,"ts_tz":1673528427,"energy_t1_a":10517.85,"energy_t2_a":1175.62,"energy_t3_a":0},"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673532000":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673535600":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"167 ...
#  'meter': {'address': 'Санкт-Петербург, Ворошилова, 2',
#            'category': 0,
#            'editAccessTypePermit': False,
#            'editPermit': False,
#            'freqReqStatus': -1,
#            'id': 2147485996,
#            'isConsumer': False,
#            'isExternal': False,
#            'isLowDataFreq': False,
#            'isOpen': True,
#            'isPulse': False,
#            'isSharedByLink': False,
#            'isViewer': True,
#            'isVirtual': False,
#            'liveMode': False,
#            'name': 'НЕВА МТ 114 (Wi-Fi) (22001114)',
#            'offerPermit': False,
#            'partner': True,
#            'prices': {'price': '3.92',
#                       'priceTF1': '4.51',
#                       'priceTF2': '2.44',
#                       'priceTF31': '4.61',
#                       'priceTF32': '2.44',
#                       'priceTF33': '3.92'},
#            'readingsPermit': False,
#            'requestSent': False,
#            'requestType': 2,
#            'serialNumber': '22001114',
#            'showCorpTariffsLink': False,
#            'showHourlyReportLink': False,
#            'subType': 0,
#            'subject': {'email': 'cloud@taipit.ru',
#                        'name': 'Компания Тайпит',
#                        'picture': '/uploads/user/photo/3edba895933a54540fbdb88614f24f480a9eeb68.png',
#                        'userId': 'a128bf64-01c0-11e8-bbef-fa163e7bc62b'},
#            'supplierPermit': False,
#            'switch': False,
#            'tariffsNum': None,
#            'viewSettingsPermit': False,
#            'warningsPermit': True,
#            'waterHot': False,
#            'withPermit': True},
#  'period': {'time': 1673528662,
#             'values': [{'energy_type': 'day',
#                         'k_iu': 1,
#                         'ts_tz': 1672531200,
#                         'value': '{"1672531200":{"t1":{"energy_a":11660.49,"ts_tz":1672531214,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"t2":{"energy_a":11660.49,"ts_tz":1672617652,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1672617600":{"t1":{"energy_a":11660.49,"ts_tz":1672617652,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"t2":{"energy_a":11660.49,"ts_tz":1672704053,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1672704000":{"t1":{"energy_a":11660.49,"ts_tz":1672704053,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"t2":{"energy_a":11660.49,"ts_tz":1672790411,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1672790400":{"t1":{"energy_a":11660.49,"ts_tz":1672790411,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"t2":{"energy_a":11660.49,"ts_tz":1672876837,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1672876800":{"t1":{"energy_a":11660.49,"ts_tz":1672876837,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"t2":{"energy_a":11660.49,"ts_tz":1672963240,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1672963200":{"t1":{"energy_a":11660.49,"ts_tz":1672963240,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"t2":{"energy_a":11660.49,"ts_tz":1673049639,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1673049600":{"t1":{"energy_a":11660.49,"ts_tz":1673049639,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"t2":{"energy_a":11660.49,"ts_tz":1673136056,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1673136000":{"t1":{"energy_a":11660.49,"ts_tz":1673136056,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"t2":{"energy_a":11660.49,"ts_tz":1673222421,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"value":0,"valueT1":0,"valueT2":0,"valueT3":0},"1673222400":{"t1":{"energy_a":11660.49,"ts_tz":1673222421,"energy_t1_a":10485.79,"energy_t2_a":1174.7,"energy_t3_a":0},"t2":{"energy_a":11670.8,"ts_tz":1673308847,"energy_t1_a":10495.5,"energy_t2_a":1175.3,"energy_t3_a":0},"value":10.31,"valueT1":9.71,"valueT2":0.6,"valueT3":0},"1673308800":{"t1":{"energy_a":11670.8,"ts_tz":1673308847,"energy_t1_a":10495.5,"energy_t2_a":1175.3,"energy_t3_a":0},"t2":{"energy_a":11680.06,"ts_tz":1673395263,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"value":9.26,"valueT1":9.26,"valueT2":0,"valueT3":0},"1673395200":{"t1":{"energy_a":11680.06,"ts_tz":1673395263,"energy_t1_a":10504.76,"energy_t2_a":1175.3,"energy_t3_a":0},"t2":{"energy_a":11688.8,"ts_tz":1673481609,"energy_t1_a":10513.18,"energy_t2_a":1175.62,"energy_t3_a":0},"value":8.74,"valueT1":8.42,"valueT2":0.32,"valueT3":0},"1673481600":{"t1":{"energy_a":11688.8,"ts_tz":1673481609,"energy_t1_a":10513.18,"energy_t2_a":1175.62,"energy_t3_a":0},"t2":{"energy_a":11693.47,"ts_tz":1673528427,"energy_t1_a":10517.85,"energy_t2_a":1175.62,"energy_t3_a":0},"value":4.67,"valueT1":4.67,"valueT2":0,"valueT3":0},"1673568000":{"t1":{"energy_a":11693.47,"ts_tz":1673528427,"energy_t1_a":10517.85,"energy_t2_a":1175.62,"energy_t3_a":0},"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673654400":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673740800":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673827200":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1673913600":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1674000000":{"t1":[],"t2":[],"value":false,"valueT1":false,"valueT2":false,"valueT3":false},"1674 ...
#  'subTypesSettings': {'12': {'red_bg_warning_period': 86400},
#                       'live_refresh_period': 60},
#  'viewers': 'public'}

# %%
# meter info
url = f"{API_URL}/meter/get-id"
for meter in all_meters_values:
#for meter in meters:
    print(f"Meter ID: {meter['id']}")
    params = {'id': meter['id']}
    r = s.get(url, params=params, headers=auth)
    print(f'URL: {r.url}')
    print(f'Status: {r.status_code}')
    meter_info = r.json()
    print('Response:')
    pprint(meter_info)
    print("\n")
# Out:
# Meter ID: 2147485997
# URL: https://cloud.meters.taipit.ru/api/meter/get-id?id=2147485997
# Status: 200
# Response:
# {'controller': {'building': '2',
#                 'city': 'Санкт-Петербург',
#                 'regionId': 78,
#                 'street': 'Ворошилова'},
#  'controllerId': '11194495496',
#  'countPeople': None,
#  'id': 2147485997,
#  'k_i_evaluation_date': '',
#  'k_i_next_evaluation_date': '',
#  'k_transf_i_denominator': None,
#  'k_transf_i_numerator': None,
#  'k_transf_u_denominator': None,
#  'k_transf_u_numerator': None,
#  'k_u_evaluation_date': '',
#  'k_u_next_evaluation_date': '',
#  'meterName': 'НЕВА МТ 114 (Wi-Fi) (22001110)',
#  'meterTypeId': 16,
#  'netAddress': '22001110',
#  'next_evaluation_date': '',
#  'password': None,
#  'privacyReadId': 1,
#  'privacyRequestReadId': 2,
#  'production_date': '',
#  'serialNumber': '22001110',
#  'tariffsNum': None}
#
#
# Meter ID: 2147485996
# URL: https://cloud.meters.taipit.ru/api/meter/get-id?id=2147485996
# Status: 200
# Response:
# {'controller': {'building': '2',
#                 'city': 'Санкт-Петербург',
#                 'regionId': 78,
#                 'street': 'Ворошилова'},
#  'controllerId': '111944954e9',
#  'countPeople': None,
#  'id': 2147485996,
#  'k_i_evaluation_date': '',
#  'k_i_next_evaluation_date': '',
#  'k_transf_i_denominator': None,
#  'k_transf_i_numerator': None,
#  'k_transf_u_denominator': None,
#  'k_transf_u_numerator': None,
#  'k_u_evaluation_date': '',
#  'k_u_next_evaluation_date': '',
#  'meterName': 'НЕВА МТ 114 (Wi-Fi) (22001114)',
#  'meterTypeId': 16,
#  'netAddress': '22001114',
#  'next_evaluation_date': '',
#  'password': None,
#  'privacyReadId': 1,
#  'privacyRequestReadId': 2,
#  'production_date': '',
#  'serialNumber': '22001114',
#  'tariffsNum': None}
